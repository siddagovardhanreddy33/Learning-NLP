# %%
# ==========================================
# NAMED ENTITY RECOGNITION (NER) TAGS - NLTK
# (Used by nltk.ne_chunk)
# ==========================================

# PERSON        -> Names of people (e.g., "Shah Jahan", "John")
# ORGANIZATION  -> Companies, institutions (e.g., "Google", "UN")
# GPE           -> Geo-Political Entity (countries, cities, states)
# LOCATION      -> Non-political places (e.g., "Himalayas")
# FACILITY      -> Buildings, airports, roads (e.g., "Taj Mahal")
# GSP           -> Geopolitical groups (rarely used)

# DATE          -> Dates (e.g., "January 1, 2020")
# TIME          -> Time expressions (e.g., "10 AM")
# MONEY         -> Monetary values (e.g., "$100")
# PERCENT       -> Percentage (e.g., "50%")

# %%
import nltk
nltk.download('punkt')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sidda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\sidda\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\sidda\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sidda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

sentence = "Taj Mahal is in India and was built by Shah Jahan in 1632"

# %%
words = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)
ner = nltk.ne_chunk(pos_tags)

# %%
print(ner)
# Out:
# (S
#   (PERSON Taj/NNP)
#   (ORGANIZATION Mahal/NNP)
#   is/VBZ
#   in/IN
#   (GPE India/NNP)
#   and/CC
#   was/VBD
#   built/VBN
#   by/IN
#   (PERSON Shah/NNP Jahan/NNP)
#   in/IN
#   1632/CD)

# %%
ner
# Out:
# Tree('S', [Tree('PERSON', [('Taj', 'NNP')]), Tree('ORGANIZATION', [('Mahal', 'NNP')]), ('is', 'VBZ'), ('in', 'IN'), Tree('GPE', [('India', 'NNP')]), ('and', 'CC'), ('was', 'VBD'), ('built', 'VBN'), ('by', 'IN'), Tree('PERSON', [('Shah', 'NNP'), ('Jahan', 'NNP')]), ('in', 'IN'), ('1632', 'CD')])

# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."
sentence
# Out:
# 'The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures.'

# %%
import nltk
words = nltk.word_tokenize(sentence)

# %%
tagged_elements = nltk.pos_tag(words)

# %%
ner = nltk.ne_chunk(tagged_elements)

# %%
ner
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('was', 'VBD'), ('built', 'VBN'), ('from', 'IN'), ('1887', 'CD'), ('to', 'TO'), ('1889', 'CD'), ('by', 'IN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('whose', 'WP$'), ('company', 'NN'), ('specialized', 'VBD'), ('in', 'IN'), ('building', 'NN'), ('metal', 'NN'), ('frameworks', 'NNS'), ('and', 'CC'), ('structures', 'NNS'), ('.', '.')])
