# %% [markdown]
# ## 🔹 5. Model Building
#
# **Goal:** Train model on features
#
# ### ML Models:
#
# * Naive Bayes
# * Logistic Regression
# * SVM
#
# ### Deep Learning:
#
# * RNN
# * LSTM
# * Transformers (modern standard)
#
# 👉 Today, most real-world NLP uses **Transformers**
