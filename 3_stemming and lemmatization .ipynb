# %% [markdown]
# ## 🔹 3. Stemming vs Lemmatization
#
# **Goal:** Reduce words to base form
#
# ### Stemming (crude):
#
# * Running → run
# * Studies → studi ❗
#
# ### Lemmatization (accurate):
#
# * Running → run
# * Better → good ✅
#
# 👉 Lemmatization uses vocabulary + grammar → **more meaningful**

# %% [markdown]
# ##### Stemming is the process of reducing a word to its root/base form by removing suffixes.
#
# ### Simple Definition
# - “Stemming is a rule-based process that cuts off prefixes or suffixes from words to obtain a root form, which may not always be a valid English word.”

# %% [markdown]
# - stemming is a process of reducing the word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma . stemming in important in nalural language understanding(NLU) and natural language processing (NLP)

# %%
words = [
    "playing", "running", "happiness", "studies", "connection",
    "flying", "easily", "fairly", "walking", "talked",
    "talking", "talks", "runner", "relational", "conditional",
    "rational", "valency", "hesitancy", "digitizer", "conformably",
    "radically", "different", "vilely", "analogously", "vietnamization",
    "predication", "operator", "feudalism", "decisiveness", "hopefulness",
    "callousness", "formaliti", "sensitiviti", "sensibiliti", "triplicate",
    "formative", "formalize", "electricity", "electrical", "hopeful",
    "goodness", "revival", "allowance", "inference", "airliner",
    "gyroscopic", "adjustable", "defensible", "irritant", "replacement"
]

# %%
corpus = [
    "running",
    "studies",
    "better",
    "flying",
    "leaves",
    "mice",
    "geese",
    "went",
    "cars",
    "playing",
    "happiness",
    "quickly",
    "cats",
    "writing",
    "ate",
    "feet",
    "buying",
    "driving",
    "children",
    "swimming"
]

# %%
words
# Out:
# ['playing',
#  'running',
#  'happiness',
#  'studies',
#  'connection',
#  'flying',
#  'easily',
#  'fairly',
#  'walking',
#  'talked',
#  'talking',
#  'talks',
#  'runner',
#  'relational',
#  'conditional',
#  'rational',
#  'valency',
#  'hesitancy',
#  'digitizer',
#  'conformably',
#  'radically',
#  'different',
#  'vilely',
#  'analogously',
#  'vietnamization',
#  'predication',
#  'operator',
#  'feudalism',
#  'decisiveness',
#  'hopefulness',
#  'callousness',
#  'formaliti',
#  'sensitiviti',
#  'sensibiliti',
#  'triplicate',
#  'formative',
#  'formalize',
#  'electricity',
#  'electrical',
#  'hopeful',
#  'goodness',
#  'revival',
#  'allowance',
#  'inference',
#  'airliner',
#  'gyroscopic',
#  'adjustable',
#  'defensible',
#  'irritant',
#  'replacement']

# %% [markdown]
# ## PoterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word + '------>' + stemming.stem(word))
# Out:
# playing------>play
# running------>run
# happiness------>happi
# studies------>studi
# connection------>connect
# flying------>fli
# easily------>easili
# fairly------>fairli
# walking------>walk
# talked------>talk
# talking------>talk
# talks------>talk
# runner------>runner
# relational------>relat
# conditional------>condit
# rational------>ration
# valency------>valenc
# hesitancy------>hesit
# digitizer------>digit
# conformably------>conform
# radically------>radic
# different------>differ
# vilely------>vile
# analogously------>analog
# vietnamization------>vietnam
# predication------>predic
# operator------>oper
# feudalism------>feudal
# decisiveness------>decis
# hopefulness------>hope
# callousness------>callous
# formaliti------>formal
# sensitiviti------>sensit
# sensibiliti------>sensibl
# triplicate------>triplic
# formative------>form
# formalize------>formal
# electricity------>electr
# electrical------>electr
# hopeful------>hope
# goodness------>good
# revival------>reviv
# allowance------>allow
# inference------>infer
# airliner------>airlin
# gyroscopic------>gyroscop
# adjustable------>adjust
# defensible------>defens
# irritant------>irrit
# replacement------>replac

# %%
for word in corpus:
    print(word + '------>' + stemming.stem(word))
# Out:
# running------>run
# studies------>studi
# better------>better
# flying------>fli
# leaves------>leav
# mice------>mice
# geese------>gees
# went------>went
# cars------>car
# playing------>play
# happiness------>happi
# quickly------>quickli
# cats------>cat
# writing------>write
# ate------>ate
# feet------>feet
# buying------>buy
# driving------>drive
# children------>children
# swimming------>swim

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('sitting')
# Out:
# 'sit'

# %%
stemming.stem('batting')
# Out:
# 'bat'

# %% [markdown]
# ### RegexpStemmer class
# - NLTK has RegexStemmer class with the help of which we can easily implement Regulaar Expression Stemmer algorithms . it basically takes a single regular expression and removes any prefix or suffix matches the expression

# %%
from nltk.stem import RegexpStemmer

# %%
# syntax 

#(regexp: Any, min: int = 0) -> RegexpStemmer
#regexp: str or regexp


# A stemmer that uses regular expressions to identify morphological affixes. Any substrings that match the regular expressions will be removed.

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$',min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %%
for word in words:
    print(word +'---->'+ reg_stemmer.stem(word))
# Out:
# playing---->play
# running---->runn
# happiness---->happines
# studies---->studie
# connection---->connection
# flying---->fly
# easily---->easily
# fairly---->fairly
# walking---->walk
# talked---->talked
# talking---->talk
# talks---->talk
# runner---->runner
# relational---->relational
# conditional---->conditional
# rational---->rational
# valency---->valency
# hesitancy---->hesitancy
# digitizer---->digitizer
# conformably---->conformably
# radically---->radically
# different---->different
# vilely---->vilely
# analogously---->analogously
# vietnamization---->vietnamization
# predication---->predication
# operator---->operator
# feudalism---->feudalism
# decisiveness---->decisivenes
# hopefulness---->hopefulnes
# callousness---->callousnes
# formaliti---->formaliti
# sensitiviti---->sensitiviti
# sensibiliti---->sensibiliti
# triplicate---->triplicat
# formative---->formativ
# formalize---->formaliz
# electricity---->electricity
# electrical---->electrical
# hopeful---->hopeful
# goodness---->goodnes
# revival---->revival
# allowance---->allowanc
# inference---->inferenc
# airliner---->airliner
# gyroscopic---->gyroscopic
# adjustable---->adjust
# defensible---->defensibl
# irritant---->irritant
# replacement---->replacement

# %%
for word in corpus:
    print(word +'---->'+ reg_stemmer.stem(word))
# Out:
# running---->runn
# studies---->studie
# better---->better
# flying---->fly
# leaves---->leave
# mice---->mic
# geese---->gees
# went---->went
# cars---->car
# playing---->play
# happiness---->happines
# quickly---->quickly
# cats---->cat
# writing---->writ
# ate---->ate
# feet---->feet
# buying---->buy
# driving---->driv
# children---->children
# swimming---->swimm

# %%
reg_stemmer.stem(word)
# Out:
# 'swimm'

# %% [markdown]
# ### Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
SnowballStemmer =SnowballStemmer('english')

# %%
for word in words:
    print(word + '----->' + SnowballStemmer.stem(word))
# Out:
# playing----->play
# running----->run
# happiness----->happi
# studies----->studi
# connection----->connect
# flying----->fli
# easily----->easili
# fairly----->fair
# walking----->walk
# talked----->talk
# talking----->talk
# talks----->talk
# runner----->runner
# relational----->relat
# conditional----->condit
# rational----->ration
# valency----->valenc
# hesitancy----->hesit
# digitizer----->digit
# conformably----->conform
# radically----->radic
# different----->differ
# vilely----->vile
# analogously----->analog
# vietnamization----->vietnam
# predication----->predic
# operator----->oper
# feudalism----->feudal
# decisiveness----->decis
# hopefulness----->hope
# callousness----->callous
# formaliti----->formal
# sensitiviti----->sensit
# sensibiliti----->sensibl
# triplicate----->triplic
# formative----->format
# formalize----->formal
# electricity----->electr
# electrical----->electr
# hopeful----->hope
# goodness----->good
# revival----->reviv
# allowance----->allow
# inference----->infer
# airliner----->airlin
# gyroscopic----->gyroscop
# adjustable----->adjust
# defensible----->defens
# irritant----->irrit
# replacement----->replac

# %%
for word in corpus:
    print(word + '----->' + SnowballStemmer.stem(word))
# Out:
# running----->run
# studies----->studi
# better----->better
# flying----->fli
# leaves----->leav
# mice----->mice
# geese----->gees
# went----->went
# cars----->car
# playing----->play
# happiness----->happi
# quickly----->quick
# cats----->cat
# writing----->write
# ate----->ate
# feet----->feet
# buying----->buy
# driving----->drive
# children----->children
# swimming----->swim

# %%
stemming.stem('fairly'),stemming.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
SnowballStemmer.stem('fairly')
# Out:
# 'fair'

# %%
SnowballStemmer.stem('sportly')
# Out:
# 'sport'

# %%
SnowballStemmer.stem('going')
# Out:
# 'go'

# %%
SnowballStemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('going'),stemming.stem('goes')
# Out:
# ('go', 'goe')

# %%
for i in words:
    print(i + '--->' + stemming.stem(i)+ '<--->'+SnowballStemmer.stem(i))
# Out:
# playing--->play<--->play
# running--->run<--->run
# happiness--->happi<--->happi
# studies--->studi<--->studi
# connection--->connect<--->connect
# flying--->fli<--->fli
# easily--->easili<--->easili
# fairly--->fairli<--->fair
# walking--->walk<--->walk
# talked--->talk<--->talk
# talking--->talk<--->talk
# talks--->talk<--->talk
# runner--->runner<--->runner
# relational--->relat<--->relat
# conditional--->condit<--->condit
# rational--->ration<--->ration
# valency--->valenc<--->valenc
# hesitancy--->hesit<--->hesit
# digitizer--->digit<--->digit
# conformably--->conform<--->conform
# radically--->radic<--->radic
# different--->differ<--->differ
# vilely--->vile<--->vile
# analogously--->analog<--->analog
# vietnamization--->vietnam<--->vietnam
# predication--->predic<--->predic
# operator--->oper<--->oper
# feudalism--->feudal<--->feudal
# decisiveness--->decis<--->decis
# hopefulness--->hope<--->hope
# callousness--->callous<--->callous
# formaliti--->formal<--->formal
# sensitiviti--->sensit<--->sensit
# sensibiliti--->sensibl<--->sensibl
# triplicate--->triplic<--->triplic
# formative--->form<--->format
# formalize--->formal<--->formal
# electricity--->electr<--->electr
# electrical--->electr<--->electr
# hopeful--->hope<--->hope
# goodness--->good<--->good
# revival--->reviv<--->reviv
# allowance--->allow<--->allow
# inference--->infer<--->infer
# airliner--->airlin<--->airlin
# gyroscopic--->gyroscop<--->gyroscop
# adjustable--->adjust<--->adjust
# defensible--->defens<--->defens
# irritant--->irrit<--->irrit
# replacement--->replac<--->replac

# %%
for i in corpus:
    print(i + '--->' + stemming.stem(i)+ '<--->'+SnowballStemmer.stem(i))
# Out:
# running--->run<--->run
# studies--->studi<--->studi
# better--->better<--->better
# flying--->fli<--->fli
# leaves--->leav<--->leav
# mice--->mice<--->mice
# geese--->gees<--->gees
# went--->went<--->went
# cars--->car<--->car
# playing--->play<--->play
# happiness--->happi<--->happi
# quickly--->quickli<--->quick
# cats--->cat<--->cat
# writing--->write<--->write
# ate--->ate<--->ate
# feet--->feet<--->feet
# buying--->buy<--->buy
# driving--->drive<--->drive
# children--->children<--->children
# swimming--->swim<--->swim

# %% [markdown]
# # Lemmatization
# - lemmatization technique is like stemming.
# - the output we will get after lemmatization is called 'lemma' , which is a root word rather than root stem , the output of stemming . after lemmatization we will be getting a valid word that means the same thing

# %% [markdown]
# ### WordNet Lemmatizer
#
# - NLTK provides WordNetLemmatizer class which is a wrapper around the wordnet corpus
# - this uses morphy() function to the WordNet corpusReader class to find a lemma

# %%
corpus = [
    "running",
    "studies",
    "better",
    "flying",
    "leaves",
    "mice",
    "geese",
    "went",
    "cars",
    "playing",
    "happiness",
    "quickly",
    "cats",
    "writing",
    "ate",
    "feet",
    "buying",
    "driving",
    "children",
    "swimming"
]

# %%
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sidda\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
WordNetLemmatizer = WordNetLemmatizer()
WordNetLemmatizer

# %%
for i in corpus:
    print(i + '--->' + WordNetLemmatizer.lemmatize(i))
# Out:
# running--->running
# studies--->study
# better--->better
# flying--->flying
# leaves--->leaf
# mice--->mouse
# geese--->goose
# went--->went
# cars--->car
# playing--->playing
# happiness--->happiness
# quickly--->quickly
# cats--->cat
# writing--->writing
# ate--->ate
# feet--->foot
# buying--->buying
# driving--->driving
# children--->child
# swimming--->swimming

# %%
for i in words:
    print(i + '--->' + WordNetLemmatizer.lemmatize(i))
# Out:
# playing--->playing
# running--->running
# happiness--->happiness
# studies--->study
# connection--->connection
# flying--->flying
# easily--->easily
# fairly--->fairly
# walking--->walking
# talked--->talked
# talking--->talking
# talks--->talk
# runner--->runner
# relational--->relational
# conditional--->conditional
# rational--->rational
# valency--->valency
# hesitancy--->hesitancy
# digitizer--->digitizer
# conformably--->conformably
# radically--->radically
# different--->different
# vilely--->vilely
# analogously--->analogously
# vietnamization--->vietnamization
# predication--->predication
# operator--->operator
# feudalism--->feudalism
# decisiveness--->decisiveness
# hopefulness--->hopefulness
# callousness--->callousness
# formaliti--->formaliti
# sensitiviti--->sensitiviti
# sensibiliti--->sensibiliti
# triplicate--->triplicate
# formative--->formative
# formalize--->formalize
# electricity--->electricity
# electrical--->electrical
# hopeful--->hopeful
# goodness--->goodness
# revival--->revival
# allowance--->allowance
# inference--->inference
# airliner--->airliner
# gyroscopic--->gyroscopic
# adjustable--->adjustable
# defensible--->defensible
# irritant--->irritant
# replacement--->replacement

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()
wnl

# %%
print(wnl.lemmatize('dogs'))

print(wnl.lemmatize('churches'))
print(wnl.lemmatize('aardwolves'))
print(wnl.lemmatize('abaci'))
# Out:
# dog
# church
# aardwolf
# abacus
